# %% [markdown]
# # Preprocessing Notebook
#
# **Purpose:** Convert selected columns to numeric, handle missing values, save clean dataset for modeling.

# %%
import pandas as pd
from preprocessing import preprocessing_pipeline

# Load dataset
df = pd.read_csv("../data/processed/fe_customer_churn.csv")

# %%
# Import preprocessing utilities from the project package
# The project has been installed in editable mode (pip install -e .),
# so modules can be imported directly without modifying sys.path

# Apply preprocessing
df = preprocessing_pipeline(df)
                          
# Verify dataset after preprocessing
df.info()
df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7032 entries, 0 to 7042
# Data columns (total 24 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   customerID                    7032 non-null   object
#  1   gender                        7032 non-null   object
#  2   SeniorCitizen                 7032 non-null   int64
#  3   Partner                       7032 non-null   object
#  4   Dependents                    7032 non-null   object
#  5   tenure                        7032 non-null   int64
#  6   PhoneService                  7032 non-null   object
#  7   MultipleLines                 7032 non-null   object
#  8   InternetService               7032 non-null   object
#  9   OnlineSecurity                7032 non-null   object
#  10  OnlineBackup                  7032 non-null   object
#  11  DeviceProtection              7032 non-null   object
# ...

# %%
# After preprocessing, the dataset is fully numeric and model-ready.
# Save cleaned and preprocessed dataset for modeling
df.to_csv("../data/processed/clean_customer_churn.csv", index=False)
